# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("houses_train.csv")
# data2=data[['max_floor','num_rooms','area','num_bathrooms','floor']]
# y=data['price']
data = data[data['street'] != 'Northern Ave'] 
#Northern Ave street values are not well correlated with other values in linear model.
len(data)
# Out:
# 4978

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score, cross_val_predict

# %%
y=data['price']
#data3=pd.get_dummies(data[['max_floor','num_rooms','area','num_bathrooms','floor','ceiling_height','district','condition','building_type','street']])
#Street has too many unique values, so I excluded it.
#It is possible to group street values, to leave main streets that have 
#many buildings as they are and others group in one group named Others.
#But it will be difficult for predicting new comping datas (testing).
#We can use District instead of Street.
data1=pd.get_dummies(data[['max_floor','num_rooms','area','num_bathrooms','floor','ceiling_height','condition','building_type','district']])

# %%
# x_train, x_test, y_train, y_test = train_test_split(data1, y, test_size=0.2)

# lreg = linear_model.LinearRegression()
# model = lreg.fit(x_train, y_train)
# predicttest = lreg.predict(x_test)
# predicttrain = lreg.predict(x_train)

# print ('Train RMSE:', np.sqrt(mean_squared_error(predicttrain, y_train)))
# print ('Test RMSE:', np.sqrt(mean_squared_error(predicttest, y_test)))
# Out:
# Train RMSE: 27494.822711343662
# Test RMSE: 26961.192247202594

# %%
# scores = cross_val_score(model, data1, y, cv=5,scoring='neg_root_mean_squared_error')
# print ('Cross-validated scores:', scores)
# Out:
# Cross-validated scores: [-28001.51294607 -26089.55688545 -29850.0277826  -25058.97946416
#  -28365.60609722]

# %%
from sklearn.linear_model import Ridge

# %%
# rreg = Ridge(alpha=0.001)
# rreg.fit(data1, y)
# pred = rreg.predict(data1)


# print ('Test RMSE:', np.sqrt(mean_squared_error(pred, y)))
# #alpha=0.001 Test RMSE: 27373.850655418333
# #alpha=100 Test RMSE: 27526.110464209094
# #alpha=0 Test RMSE: 27374.16855151773
# Out:
# Test RMSE: 27373.8506535575

# %%
from matplotlib import pyplot as plt

# %%
#plt.plot(data2.area, y)

# %%
#the best result 
lreg = linear_model.LinearRegression()
model = lreg.fit(data1, y)
predict = lreg.predict(data1)


print ('Test RMSE:', np.sqrt(mean_squared_error(predict, y)))
# Out:
# Test RMSE: 27373.850653538677
